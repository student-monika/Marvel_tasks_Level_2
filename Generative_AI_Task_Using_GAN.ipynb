# %% [markdown]
# <a href="https://colab.research.google.com/github/student-monika/Marvel_tasks_Level_2/blob/main/Generative_AI_Task_Using_GAN.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import torch
import torch.nn as nn
import torch.optim as optim
import torchvision
import torchvision.transforms as transforms
import matplotlib.pyplot as plt

# Hyperparameters
latent_dim = 100
epochs = 100
batch_size = 64
lr = 0.0002
device = torch.device("cuda" if torch.cuda.is_available() else "cpu")

# Load CIFAR-10 dataset
transform = transforms.Compose([transforms.ToTensor(), transforms.Normalize((0.5,), (0.5,))])
dataset = torchvision.datasets.CIFAR10(root="./data", train=True, transform=transform, download=True)
dataloader = torch.utils.data.DataLoader(dataset, batch_size=batch_size, shuffle=True)

# Generator
class Generator(nn.Module):
    def __init__(self):
        super(Generator, self).__init__()
        self.model = nn.Sequential(
            nn.Linear(latent_dim, 256),
            nn.ReLU(),
            nn.Linear(256, 512),
            nn.ReLU(),
            nn.Linear(512, 32*32*3),
            nn.Tanh()
        )

    def forward(self, z):
        return self.model(z).view(-1, 3, 32, 32)

generator = Generator().to(device)

# Discriminator
class Discriminator(nn.Module):
    def __init__(self):
        super(Discriminator, self).__init__()
        self.model = nn.Sequential(
            nn.Linear(32*32*3, 512),
            nn.LeakyReLU(0.2),
            nn.Linear(512, 256),
            nn.LeakyReLU(0.2),
            nn.Linear(256, 1),
            nn.Sigmoid()
        )

    def forward(self, img):
        return self.model(img.view(-1, 32*32*3))

discriminator = Discriminator().to(device)

# Loss and Optimizers
criterion = nn.BCELoss()
g_optimizer = optim.Adam(generator.parameters(), lr=lr, betas=(0.5, 0.999))
d_optimizer = optim.Adam(discriminator.parameters(), lr=lr, betas=(0.5, 0.999))

# Training
for epoch in range(epochs):
    for imgs, _ in dataloader:
        imgs = imgs.to(device)
        batch_size = imgs.size(0)
        real_labels = torch.ones(batch_size, 1).to(device)
        fake_labels = torch.zeros(batch_size, 1).to(device)

        # Train Discriminator
        d_optimizer.zero_grad()
        real_loss = criterion(discriminator(imgs), real_labels)
        z = torch.randn(batch_size, latent_dim).to(device)
        fake_imgs = generator(z)
        fake_loss = criterion(discriminator(fake_imgs.detach()), fake_labels)
        d_loss = real_loss + fake_loss
        d_loss.backward()
        d_optimizer.step()

        # Train Generator
        g_optimizer.zero_grad()
        fake_loss = criterion(discriminator(fake_imgs), real_labels)
        fake_loss.backward()
        g_optimizer.step()

    print(f"Epoch [{epoch+1}/{epochs}] - D Loss: {d_loss.item():.4f}, G Loss: {fake_loss.item():.4f}")

    if (epoch + 1) % 25 == 0:
        with torch.no_grad():
            z = torch.randn(16, latent_dim).to(device)
            generated_imgs = generator(z).cpu()
            grid = torchvision.utils.make_grid(generated_imgs, normalize=True)
            plt.imshow(grid.permute(1, 2, 0))
            plt.show()

print("GAN Training Complete!")
# Out:
# Epoch [1/100] - D Loss: 0.0037, G Loss: 4.9719
# Epoch [2/100] - D Loss: 0.0341, G Loss: 5.6071
# Epoch [3/100] - D Loss: 0.1106, G Loss: 5.3986
# Epoch [4/100] - D Loss: 0.0826, G Loss: 4.8794
# Epoch [5/100] - D Loss: 0.5794, G Loss: 4.3742
# Epoch [6/100] - D Loss: 0.6155, G Loss: 3.5322
# Epoch [7/100] - D Loss: 0.7105, G Loss: 3.2556
# Epoch [8/100] - D Loss: 0.8812, G Loss: 3.6282
# Epoch [9/100] - D Loss: 1.0548, G Loss: 2.6771
# Epoch [10/100] - D Loss: 0.7768, G Loss: 2.3487
# Epoch [11/100] - D Loss: 1.1610, G Loss: 2.3382
# Epoch [12/100] - D Loss: 0.8146, G Loss: 2.0192
# Epoch [13/100] - D Loss: 0.9505, G Loss: 2.5247
# Epoch [14/100] - D Loss: 1.3104, G Loss: 1.7272
# Epoch [15/100] - D Loss: 0.9935, G Loss: 1.5619
# Epoch [16/100] - D Loss: 1.2133, G Loss: 1.6315
# Epoch [17/100] - D Loss: 1.1507, G Loss: 2.1133
# Epoch [18/100] - D Loss: 0.8846, G Loss: 2.3907
# Epoch [19/100] - D Loss: 1.1657, G Loss: 1.4100
# Epoch [20/100] - D Loss: 1.1437, G Loss: 1.9166
# ...
